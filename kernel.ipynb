# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['data.csv']

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
df = pd.read_csv('../input/data.csv')
df.head()
# Out:
#    Unnamed: 0      ID       ...       GKReflexes  Release Clause
# 0           0  158023       ...              8.0         €226.5M
# 1           1   20801       ...             11.0         €127.1M
# 2           2  190871       ...             11.0         €228.1M
# 3           3  193080       ...             94.0         €138.6M
# 4           4  192985       ...             13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %% [markdown]
# ## Number of players at each age

# %%
import cufflinks as cf
import matplotlib.pyplot as plt
cf.set_config_file(offline=False, world_readable=True, theme='ggplot')

n_df = df.sort_values(by = 'Age', ascending = False)
age = n_df['Age'].values
fig = go.Histogram(x = age)
iplot([fig])
# Out:
# <div id="0e0021d5-4896-4e20-a827-f6cc0caca180" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0e0021d5-4896-4e20-a827-f6cc0caca180", [{"x": [45, 44, 44, 42, 41, 41, 41, 41, 41, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 39, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 38, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 36, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 34, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 3 ...

# %% [markdown]
# ##  5 Best player in world

# %%
ovr = df.sort_values(by = 'Overall', ascending=False)
top_best = ovr.loc[:4, ['Name', 'Overall']]
top_best
#arr = top_best.values
#a, b = zip(*arr)
#fig = go.Bar(x = a, y= b)
#iplot([fig])
# Out:
#                 Name  Overall
# 0           L. Messi       94
# 1  Cristiano Ronaldo       94
# 2          Neymar Jr       92
# 3             De Gea       91
# 4       K. De Bruyne       91

# %% [markdown]
# ## Does age affect overall rating?

# %%
age = df.sort_values(by = 'Age')
age.head()
rel = age.loc[:,[ 'Age','Overall']]
rel.values

fig = go.Scatter(x= rel['Age'] , y= rel['Overall'])
layout = go.Layout(title = 'Age Overall relationship')
figure = go.Figure(data=[fig], layout=layout)
iplot(figure)
# Out:
# <div id="dd090a59-7829-4a27-99aa-e66e4ded9747" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dd090a59-7829-4a27-99aa-e66e4ded9747", [{"x": [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 1 ...

# %% [markdown]
# ## Position's composition

# %%
pos_count = df['Position'].value_counts()
trace = go.Pie(labels = pos_count.index, values = pos_count.values, hole = 0.4)
data=[trace]
layout = go.Layout(
                    title = 'Percentage position')
fig = go.Figure(data, layout)
iplot(fig)
print ("Maxmimum Pos " + pos_count.idxmax(), pos_count.max())
# Out:
# <div id="a67730cf-8c23-4bb8-881b-b2b0b00884e6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a67730cf-8c23-4bb8-881b-b2b0b00884e6", [{"hole": 0.4, "labels": ["ST", "GK", "CB", "CM", "LB", "RB", "RM", "LM", "CAM", "CDM", "RCB", "LCB", "LCM", "RCM", "LW", "RW", "RDM", "LDM", "LS", "RS", "RWB", "LWB", "CF", "LAM", "RAM", "RF", "LF"], "values": [2152, 2025, 1778, 1394, 1322, 1291, 1124, 1095, 958, 948, 662, 648, 395, 391, 381, 370, 248, 243, 207, 203, 87, 78, 74, 21, 21, 16, 15], "type": "pie", "uid": "7c130190-b786-41f2-912b-62dca3e729cf"}], {"title": {"text": "Percentage position"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("a67730cf-8c23-4bb8-881b-b2b0b00884e6"));});</script>
# Maxmimum Pos ST 2152

# %% [markdown]
# ## Best players by position

# %%
all_position = df.iloc[df.groupby('Position')['Overall'].idxmax()][['Name', 'Position']]
pos = all_position['Position'].values
all_position['Name']
# Out:
# 17          A. Griezmann
# 12              D. Godín
# 20       Sergio Busquets
# 271         Luis Alberto
# 67                Thiago
# 3                 De Gea
# 28          J. Rodríguez
# 35               Marcelo
# 24          G. Chiellini
# 11              T. Kroos
# 14              N. Kanté
# 5              E. Hazard
# 33         P. Aubameyang
# 21             E. Cavani
# 2              Neymar Jr
# 474            N. Schulz
# 129          J. Cuadrado
# 69           Azpilicueta
# 8           Sergio Ramos
# 4           K. De Bruyne
# 45              P. Pogba
# 0               L. Messi
# 25             K. Mbappé
# 7              L. Suárez
# 56        Bernardo Silva
# 450            M. Ginter
# 1      Cristiano Ronaldo
# Name: Name, dtype: object

# %% [markdown]
# ## Best young Team by position

# %%
young_team_df = df.where(df['Age']<=22)
young_team_list = young_team_df.groupby('Position')['Overall'].idxmax()
young_team = young_team_df.iloc[young_team_list]
young_team[['Position','Name']]
# Out:
#      Position              Name
# 325       CAM     Pablo Fornals
# 115        CB           N. Süle
# 583       CDM          J. Weigl
# 3295       CF         D. Kamada
# 227        CM             Rodri
# 229        GK     G. Donnarumma
# 9541      LAM         F. Sakala
# 238        LB      L. Hernández
# 160       LCB       P. Kimpembe
# 117       LCM           D. Alli
# 323       LDM        F. de Jong
# 7772       LF          F. Amuzu
# 163        LM          T. Lemar
# 329        LS         H. Lozano
# 55         LW           L. Sané
# 6640      LWB       M. Pedersen
# 417        RB         Odriozola
# 110       RCB        D. Sánchez
# 427       RCM       G. Lo Celso
# 572       RDM        L. Tousart
# 5465       RF          Rafa Mir
# 25         RM         K. Mbappé
# 589        RS  A. Saint-Maximin
# 79         RW     Marco Asensio
# 766       RWB      Pablo Maffeo
# 156        ST     Gabriel Jesus

# %%
counter = 0
for x in pos:
    posi = all_position['Position'].values
    name = all_position.where(all_position['Position']== x ).dropna()['Name'].values
    neymar = df[['Agility','BallControl','Strength','Acceleration','ShotPower','Vision']].where(df['Name']==name[0]).dropna()
    r = neymar.values
    r = r.astype(int)[0]
#r = np.append(r,r[0])
    theta = np.array(neymar.columns)
#theta = np.append(theta, theta[0])
#theta
    data = go.Scatterpolar(
                r = r,
                theta = theta,
                fill = 'toself')
    layout = go.Layout(
      polar = dict(
        radialaxis = dict(
          visible = True,
          range = [0, 100]
        )
      ),
        title = name[0],
      showlegend = False
    )
    fig = go.Figure(data=[data], layout=layout)
    iplot(fig)
# Out:
# <div id="22e90187-99e0-48bc-99c2-a2665c7ba681" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("22e90187-99e0-48bc-99c2-a2665c7ba681", [{"fill": "toself", "r": [90, 90, 62, 88, 80, 83], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "071c2cac-1a66-4867-8fe1-d3a7886109b7"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "A. Griezmann"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("22e90187-99e0-48bc-99c2-a2665c7ba681"));});</script>
# <div id="8c37b645-d7b4-4641-9b0b-a1562b2ad5ed" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8c37b645-d7b4-4641-9b0b-a1562b2ad5ed", [{"fill": "toself", "r": [58, 76, 88, 68, 67, 52], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "3fb625ef-9a2f-4c0f-9661-2a0e6920ccf1"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "D. God\u00edn"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("8c37b645-d7b4-4641-9b0b-a1562b2ad5ed"));});</script>
# <div id="1f5b7faf-c2cf-4b9a-9283-7ba48ed5f9dd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1f5b7faf-c2cf-4b9a-9283-7ba48ed5f9dd", [{"fill": "toself", "r": [66, 88, 77, 50, 61, 87], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "0e0f3714-f418-452b-bd7e-becc4fadc629"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "Sergio Busquets"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("1f5b7faf-c2cf-4b9a-9283-7ba48ed5f9dd"));});</script>
# <div id="b24fb252-4335-401e-81d5-90834b56221c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b24fb252-4335-401e-81d5-90834b56221c", [{"fill": "toself", "r": [79, 88, 67, 77, 77, 87], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "90f8db63-1c83-47b5-83ba-b2c1836cb30a"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "Luis Alberto"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("b24fb252-4335-401e-81d5-90834b56221c"));});</script>
# <div id="5e17ce7c-af1f-45b7-84f2-bfcefb4c7058" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5e17ce7c-af1f-45b7-84f2-bfcefb4c7058", [{"fill": "toself", "r": [90, 90, 59, 78, 75, 86], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "a1e57528-1949-4122-9373-09eb8b99fcc3"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "Thiago"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("5e17ce7c-af1f-45b7-84f2-bfcefb4c7058"));});</script>
# <div id="275f497e-0a17-4682-aef8-9bcd63433dfe" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("275f497e-0a17-4682-aef8-9bcd63433dfe", [{"fill": "toself", "r": [60, 42, 64, 57, 31, 68], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "4b592d38-56ed-4ad4-93b0-eb2eea9282fd"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "De Gea"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("275f497e-0a17-4682-aef8-9bcd63433dfe"));});</script>
# <div id="8cef05a5-feb8-4e4a-8728-f0dabe42f572" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8cef05a5-feb8-4e4a-8728-f0dabe42f572", [{"fill": "toself", "r": [83, 90, 68, 73, 86, 89], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "eefafc26-4857-4db3-b0fd-5d053dbea4f8"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "J. Rodr\u00edguez"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("8cef05a5-feb8-4e4a-8728-f0dabe42f572"));});</script>
# <div id="3cfc15c4-d082-4a02-9493-908dd5ad501e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3cfc15c4-d082-4a02-9493-908dd5ad501e", [{"fill": "toself", "r": [86, 92, 78, 83, 83, 82], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "6f9c82f0-5278-49c4-9023-684e01c53a38"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "Marcelo"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("3cfc15c4-d082-4a02-9493-908dd5ad501e"));});</script>
# <div id="28871adb-6dd9-41ba-acb8-e4893e313c89" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("28871adb-6dd9-41ba-acb8-e4893e313c89", [{"fill": "toself", "r": [54, 57, 89, 63, 78, 50], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "1660b2f7-a3f7-4b90-9c9b-be099edade68"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "G. Chiellini"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("28871adb-6dd9-41ba-acb8-e4893e313c89"));});</script>
# <div id="0b6ca52b-9d9b-4c9f-8a80-babe8491eceb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0b6ca52b-9d9b-4c9f-8a80-babe8491eceb", [{"fill": "toself", "r": [70, 90, 73, 64, 87, 86], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "a346db7f-3ec1-496e-ad1f-838d51bdcd89"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "T. Kroos"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("0b6ca52b-9d9b-4c9f-8a80-babe8491eceb"));});</script>
# <div id="6dec1224-e18c-4ef5-9c9f-f11e4800c4d4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6dec1224-e18c-4ef5-9c9f-f11e4800c4d4", [{"fill": "toself", "r": [82, 80, 76, 82, 71, 79], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "b0e88659-5878-4529-81d2-1ac0f6dea1c3"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "N. Kant\u00e9"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("6dec1224-e18c-4ef5-9c9f-f11e4800c4d4"));});</script>
# <div id="c3825ea9-4d82-4d37-a054-26d65bdf59d1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c3825ea9-4d82-4d37-a054-26d65bdf59d1", [{"fill": "toself", "r": [95, 94, 66, 94, 82, 89], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "32517c4f-5361-459d-8e76-86fdd317f6d0"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "E. Hazard"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("c3825ea9-4d82-4d37-a054-26d65bdf59d1"));});</script>
# <div id="c77ae365-5b11-4fdc-895d-9c53865e5427" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c77ae365-5b11-4fdc-895d-9c53865e5427", [{"fill": "toself", "r": [76, 82, 76, 93, 82, 77], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "68cbc829-f945-4294-8f63-99c072ac1f75"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "P. Aubameyang"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("c77ae365-5b11-4fdc-895d-9c53865e5427"));});</script>
# <div id="c22adcea-3737-46ad-8381-4633bade9b74" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c22adcea-3737-46ad-8381-4633bade9b74", [{"fill": "toself", "r": [77, 82, 78, 75, 87, 77], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "3dcfa4d4-89f1-4973-b0ba-789c0a3ae2f3"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "E. Cavani"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("c22adcea-3737-46ad-8381-4633bade9b74"));});</script>
# <div id="4878a2f7-0af1-4343-9772-bbcdebc8b4e1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4878a2f7-0af1-4343-9772-bbcdebc8b4e1", [{"fill": "toself", "r": [96, 95, 49, 94, 80, 87], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "abb7e834-756c-4e8a-a66d-88f36b77d379"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "Neymar Jr"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("4878a2f7-0af1-4343-9772-bbcdebc8b4e1"));});</script>
# <div id="6eeb3923-ca1a-473f-b1f0-44a36bc332ec" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6eeb3923-ca1a-473f-b1f0-44a36bc332ec", [{"fill": "toself", "r": [76, 78, 76, 88, 65, 67], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "ad7f9095-3354-4c09-8299-fff4398bfb13"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "N. Schulz"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("6eeb3923-ca1a-473f-b1f0-44a36bc332ec"));});</script>
# <div id="0ad32925-378f-466d-b6a9-3fb1ecc00605" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0ad32925-378f-466d-b6a9-3fb1ecc00605", [{"fill": "toself", "r": [91, 85, 61, 89, 84, 76], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "4ccbf1f7-8747-442c-b4b0-819e5f86d5a9"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "J. Cuadrado"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("0ad32925-378f-466d-b6a9-3fb1ecc00605"));});</script>
# <div id="c3e1730f-105a-461b-ad97-15c75ba2da5d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c3e1730f-105a-461b-ad97-15c75ba2da5d", [{"fill": "toself", "r": [72, 77, 71, 76, 68, 74], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "1780c123-4ae7-44ef-9003-df98b95b012d"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "Azpilicueta"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("c3e1730f-105a-461b-ad97-15c75ba2da5d"));});</script>
# <div id="41582546-9c22-4ec6-bea2-4dca75287652" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("41582546-9c22-4ec6-bea2-4dca75287652", [{"fill": "toself", "r": [78, 84, 83, 76, 79, 63], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "aef26780-08e7-4bf8-9eb4-55b0fae8446b"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "Sergio Ramos"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("41582546-9c22-4ec6-bea2-4dca75287652"));});</script>
# <div id="526ddf6c-3591-449a-9dc3-8a1b8a09eece" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("526ddf6c-3591-449a-9dc3-8a1b8a09eece", [{"fill": "toself", "r": [79, 91, 75, 78, 91, 94], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "2350dab6-13d7-4663-97ab-a9d47895d05d"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "K. De Bruyne"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("526ddf6c-3591-449a-9dc3-8a1b8a09eece"));});</script>
# <div id="8961f7eb-b7c8-4789-b271-cf3b8add3f41" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8961f7eb-b7c8-4789-b271-cf3b8add3f41", [{"fill": "toself", "r": [74, 90, 89, 71, 90, 87], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "25df9c56-0783-4905-8576-b64d49c65fb9"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "P. Pogba"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("8961f7eb-b7c8-4789-b271-cf3b8add3f41"));});</script>
# <div id="1ff365f5-af99-4669-9645-624fb45bb7e0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1ff365f5-af99-4669-9645-624fb45bb7e0", [{"fill": "toself", "r": [91, 96, 59, 91, 85, 94], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "52b6a987-ed89-4add-9ac2-8a0b0f00ab2a"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "L. Messi"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("1ff365f5-af99-4669-9645-624fb45bb7e0"));});</script>
# <div id="d41e3f71-462a-4e0d-8f0b-9cdf3e02f073" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d41e3f71-462a-4e0d-8f0b-9cdf3e02f073", [{"fill": "toself", "r": [92, 91, 71, 96, 79, 82], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "d0346403-705f-419d-81ad-5a5b2b3f4447"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "K. Mbapp\u00e9"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("d41e3f71-462a-4e0d-8f0b-9cdf3e02f073"));});</script>
# <div id="64305472-0008-45c7-9422-05b02fe14976" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("64305472-0008-45c7-9422-05b02fe14976", [{"fill": "toself", "r": [82, 90, 83, 86, 86, 84], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "affcc865-ce13-4685-92ea-ce2514c489c2"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "L. Su\u00e1rez"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("64305472-0008-45c7-9422-05b02fe14976"));});</script>
# <div id="b8b91f74-23c9-4ebe-875b-5c66c7d9c223" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b8b91f74-23c9-4ebe-875b-5c66c7d9c223", [{"fill": "toself", "r": [90, 91, 48, 84, 70, 86], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "dd781f49-6059-44ca-83c1-3b87274b7e61"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "Bernardo Silva"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("b8b91f74-23c9-4ebe-875b-5c66c7d9c223"));});</script>
# <div id="e894778a-e854-495d-a0d4-d3a5bedacff9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e894778a-e854-495d-a0d4-d3a5bedacff9", [{"fill": "toself", "r": [55, 72, 81, 55, 74, 68], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "4d246050-c294-4c97-aaf0-2313df9b8055"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "M. Ginter"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("e894778a-e854-495d-a0d4-d3a5bedacff9"));});</script>
# <div id="ebb0f857-69db-4732-8733-52c8b8766817" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ebb0f857-69db-4732-8733-52c8b8766817", [{"fill": "toself", "r": [87, 94, 79, 89, 95, 82], "theta": ["Agility", "BallControl", "Strength", "Acceleration", "ShotPower", "Vision"], "type": "scatterpolar", "uid": "01144036-6f8f-438b-8c28-ccae73757401"}], {"polar": {"radialaxis": {"range": [0, 100], "visible": true}}, "showlegend": false, "title": {"text": "Cristiano Ronaldo"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("ebb0f857-69db-4732-8733-52c8b8766817"));});</script>

# %%
trace1 = {
    'x' : [19],
    'y' : [25],
    'type': 'scatter',
    'name' : 'GK',
    'text': all_position['Name'].where(all_position['Position']=='GK').dropna().values,
    'marker':{'color':'pink','size':20}    
}
trace2 = {
    'x' : [25],
    'y' : [15],
    'type': 'scatter',
    'name' : 'LCB',
    'text': all_position['Name'].where(all_position['Position']=='LCB').dropna().values,
    'marker':{'color':'red','size':20}    
}
trace3 = {
    'x' : [25],
    'y' : [35],
    'type': 'scatter',
    'name' : 'RCB',
    'text': all_position['Name'].where(all_position['Position']=='RCB').dropna().values,
    'marker':{'color':'red','size':20}    
}
trace4 = {
    'x' : [30],
    'y' : [45],
    'type': 'scatter',
    'name' : 'LB',
    'text': all_position['Name'].where(all_position['Position']=='LB').dropna().values,
    'marker':{'color':'red','size':20}    
}
trace5 = {
    'x' : [30],
    'y' : [5],
    'type': 'scatter',
    'name' : 'RB',
    'text': all_position['Name'].where(all_position['Position']=='RB').dropna().values,
    'marker':{'color':'red','size':20}    
}
trace6 = {
    'x' : [40],
    'y' : [25],
    'type': 'scatter',
    'name' : 'CDM',
    'text': all_position['Name'].where(all_position['Position']=='CDM').dropna().values,
    'marker':{'color':'green','size':20}    
}
trace7 = {
    'x' : [50],
    'y' : [40],
    'type': 'scatter',
    'name' : 'LCM',
    'text': all_position['Name'].where(all_position['Position']=='LCM').dropna().values,
    'marker':{'color':'green','size':20}    
}
trace8 = {
    'x' : [50],
    'y' : [12],
    'type': 'scatter',
    'name' : 'RCM',
    'text': all_position['Name'].where(all_position['Position']=='RCM').dropna().values,
    'marker':{'color':'green','size':20}    
}
trace9 = {
    'x' : [65],
    'y' : [50],
    'type': 'scatter',
    'name' : 'LF',
    'text': all_position['Name'].where(all_position['Position']=='LF').dropna().values,
    'marker':{'color':'blue','size':20}    
}
trace10 = {
    'x' : [65],
    'y' : [2],
    'type': 'scatter',
    'name' : 'RF',
    'text': all_position['Name'].where(all_position['Position']=='RF').dropna().values,
    'marker':{'color':'blue','size':20}    
}
trace11 = {
    'x' : [60],
    'y' : [25],
    'type': 'scatter',
    'name' : 'ST',
    'text': all_position['Name'].where(all_position['Position']=='ST').dropna().values,
    'marker':{'color':'yellow','size':20}
}
Layout={
    "title":"Dream Team"
}
data=[trace1,trace2,trace3,trace4,trace5,trace6,trace7,trace8,trace9,trace10,trace11]
fig = go.Figure(data = data, layout=Layout)
iplot(fig)

# %%
trace1 = {
    'x' : [19],
    'y' : [25],
    'type': 'scatter',
    'name' : 'GK',
    'text': young_team['Name'].where(young_team['Position']=='GK').dropna().values,
    'marker':{'color':'pink','size':20}    
}
trace2 = {
    'x' : [25],
    'y' : [15],
    'type': 'scatter',
    'name' : 'LCB',
    'text': young_team['Name'].where(young_team['Position']=='LCB').dropna().values,
    'marker':{'color':'red','size':20}    
}
trace3 = {
    'x' : [25],
    'y' : [35],
    'type': 'scatter',
    'name' : 'RCB',
    'text': young_team['Name'].where(young_team['Position']=='RCB').dropna().values,
    'marker':{'color':'red','size':20}    
}
trace4 = {
    'x' : [30],
    'y' : [45],
    'type': 'scatter',
    'name' : 'LB',
    'text': young_team['Name'].where(young_team['Position']=='LB').dropna().values,
    'marker':{'color':'red','size':20}    
}
trace5 = {
    'x' : [30],
    'y' : [5],
    'type': 'scatter',
    'name' : 'RB',
    'text': young_team['Name'].where(young_team['Position']=='RB').dropna().values,
    'marker':{'color':'red','size':20}    
}
trace6 = {
    'x' : [40],
    'y' : [25],
    'type': 'scatter',
    'name' : 'CDM',
    'text': young_team['Name'].where(young_team['Position']=='CDM').dropna().values,
    'marker':{'color':'green','size':20}    
}
trace7 = {
    'x' : [50],
    'y' : [40],
    'type': 'scatter',
    'name' : 'LCM',
    'text': young_team['Name'].where(young_team['Position']=='LCM').dropna().values,
    'marker':{'color':'green','size':20}    
}
trace8 = {
    'x' : [50],
    'y' : [12],
    'type': 'scatter',
    'name' : 'RCM',
    'text': young_team['Name'].where(young_team['Position']=='RCM').dropna().values,
    'marker':{'color':'green','size':20}    
}
trace9 = {
    'x' : [65],
    'y' : [50],
    'type': 'scatter',
    'name' : 'LF',
    'text': young_team['Name'].where(young_team['Position']=='LF').dropna().values,
    'marker':{'color':'blue','size':20}    
}
trace10 = {
    'x' : [65],
    'y' : [2],
    'type': 'scatter',
    'name' : 'RF',
    'text': young_team['Name'].where(young_team['Position']=='RF').dropna().values,
    'marker':{'color':'blue','size':20}    
}
trace11 = {
    'x' : [60],
    'y' : [25],
    'type': 'scatter',
    'name' : 'ST',
    'text': young_team['Name'].where(young_team['Position']=='ST').dropna().values,
    'marker':{'color':'yellow','size':20}
}
Layout={
    "title":"Young player's team under 22"
}
data=[trace1,trace2,trace3,trace4,trace5,trace6,trace7,trace8,trace9,trace10,trace11]
fig = go.Figure(data=data, layout=Layout)
iplot(fig)
# Out:
# <div id="7b2dcc89-d8ca-4cc6-b565-94f45a62bd11" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7b2dcc89-d8ca-4cc6-b565-94f45a62bd11", [{"marker": {"color": "pink", "size": 20}, "name": "GK", "text": ["G. Donnarumma"], "x": [19], "y": [25], "type": "scatter", "uid": "78935a39-d934-49a5-a0f2-aad379bac8ce"}, {"marker": {"color": "red", "size": 20}, "name": "LCB", "text": ["P. Kimpembe"], "x": [25], "y": [15], "type": "scatter", "uid": "5d06be3e-5a95-4efb-8717-3e00c35a8c23"}, {"marker": {"color": "red", "size": 20}, "name": "RCB", "text": ["D. S\u00e1nchez"], "x": [25], "y": [35], "type": "scatter", "uid": "1f24084c-89ed-4753-87f2-3528f07e86fe"}, {"marker": {"color": "red", "size": 20}, "name": "LB", "text": ["L. Hern\u00e1ndez"], "x": [30], "y": [45], "type": "scatter", "uid": "09e66c9a-9412-456c-a2d5-19990acc70b3"}, {"marker": {"color": "red", "size": 20}, "name": "RB", "text": ["Odriozola"], "x": [30], "y": [5], "type": "scatter", "uid": "95503aa4-fc25-44ec-b766-346bcf365ec1"}, {"marker": {"color": "green", "size": 20}, "name": "CDM", "text": ["J. Weigl"], "x": [40], "y": [25], "type": "scatter", "uid": "cad1f1a7-02bd-499c-8c2a-34310594fdc8"}, {"marker": {"color": "green", "size": 20}, "name": "LCM", "text": ["D. Alli"], "x": [50], "y": [40], "type": "scatter", "uid": "6fc1c3b4-ec02-4a27-9da9-18d9f2982398"}, {"marker": {"color": "green", "size": 20}, "name": "RCM", "text": ["G. Lo Celso"], "x": [50], "y": [12], "type": "scatter", "uid": "21018d2a-9e2e-46a0-af2d-26c746707548"}, {"marker": {"color": "blue", "size": 20}, "name": "LF", "text": ["F. Amuzu"], "x": [65], "y": [50], "type": "scatter", "uid": "fbe33a37-2144-49e6-8c5e-52ddd547b70d"}, {"marker": {"color": "blue", "size": 20}, "name": "RF", "text": ["Rafa Mir"], "x": [65], "y": [2], "type": "scatter", "uid": "935c3b68-2796-45c7-a722-4fddcfb219df"}, {"marker": {"color": "yellow", "size": 20}, "name": "ST", "text": ["Gabriel Jesus"], "x": [60], "y": [25], "type": "scatter", "uid": "8538bc60-7607-4421-91ec-22cb7b8d384b"}], {"title": {"text": "Young player's team under 22"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("7b2dcc89-d8ca-4cc6-b565-94f45a62bd11"));});</script>
